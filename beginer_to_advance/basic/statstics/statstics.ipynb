# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import statistics

# %%
#mean,median,mode
df =sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %%
np.median(df["total_bill"])
# Out:
# 17.795

# %%
statistics.mode(df["total_bill"])
# Out:
# 13.42

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(df["total_bill"] ) #we dont know its is nd ? or sd ////?
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df["total_bill"] ,kde=True)#we used kde to know its nd or not but here it is skewed to left so its not normal distribution
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df1=sns.load_dataset('iris')

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df1["sepal_width"],kde=True) #perfect its is guassian distrubution
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.countplot(df1["species"])
# Out:
# <Axes: xlabel='count', ylabel='species'>

# %%
#to find outliers 

#to find percentile we use
np.percentile(df1['sepal_length'],[25,75])
#my percentile
# Out:
# array([5.1, 6.4])

# %%
#to find outliers

# %%
#lets define our own datset
dataset=[11,10,12,14,12,15,14,13,15,102,12,14,17,19,107, 10,13,12,14,12,108,12,11,14,13,15,10,15,12,10,14,13,15,10]

# %%
outliers=[]
def detect_outlier(data):
    
    threshold =3 # 3std
    mean=np.mean(data)
    std=np.std(data)

    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
            
    return outliers

# %%
detect_outlier(dataset)
# Out:
# [102, 107, 108]

# %%
#IQR
    """
    sort the data 
    calculate q1 and q3
    find lower fence q1 - 1.5(iqr)
    find upper fence q3 +1.5(iqr)


"""

# %%
dataset =sorted(dataset)
dataset
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  17,
#  19,
#  102,
#  107,
#  108]

# %%
#l
q1,q3 =np.percentile(dataset,[25,75])

# %%
print(q1,q3)
# Out:
# 12.0 15.0

# %%
#iqr
iqr=(q3-q1)
iqr
# Out:
# 3.0

# %%
#finding lower and higher fence

lower_fence = q1 - (1.5*iqr)
higher_fence = q3+(1.5*iqr)
lower_fence,higher_fence
# Out:
# (7.5, 19.5)

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >
